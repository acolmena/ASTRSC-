# %% [markdown]
# # Lemmatization & Stemming of All Words in Dictionaries
# Since the website's code was modified such that it is able to highlight any word in text that matches a word in any of the arrays/dictionaries plus any **suffix** inflections of the words, we will now reduce the current dictionary words to their stems. Many of the words currently in the dictionaries appear only in their inflected forms, meaning we risk not detecting the stems and other inflections of these words. For instance, if we only have the word 'collapsing' in our dictionary, ASTRSC will not be able to detect the words 'collapse', 'collapses', and 'collapsed'. Hence, in reducing 'collapsing' to its stem, ASTRSC would be able to detect all listed words.
#
# Author: Anabelle Colmenares

# %% [markdown]
# ## Import Libraries
# We will first import all necessary libraries

# %%
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# ## Process Arrays
# We will then insert all current arrays into a dictionary and process them to extract the stems of all words in them.

# %%
whitelistArray = [
    "pan-african",
    "pan african",
    "african studies",
    "african union",
    "south africa",
    "west africa",
    "north africa",
    "east africa",
    "southern africa",
    "northern africa",
    "eastern africa",
    "western africa",
    "african american",
  ]

generalizationArray = [
    "africa",
    "subsaharan",
    "continent",
    "sub-saharan",
  ]

tribalismArray = [
    "ethnic",
    "nomadic",
    "bushmen",
    "tribe",
    "pygmy",
    "tribal",
  ]

natureArray = [
    "wildlife",
    "fauna",
    "habitat",
    "habitats",
    "conservation",
    "animals",
    "birds",
    "animal",
    "flora",
    "livestock",
    "hunting",
    "parks",
    "biota",
    "geese",
    "egyptian geese",
    "egyptian goose",
    "goose",
    "wilderness",
    "wild",
    "park",
    "natural",
    "nature",
    "hunt",
    "camping",
    "wildcat",
    "sauvage",
    "savage",
    "wild-type",
    "waterfowl",
    "deer",
    "barbary stag",
    "ecology",
    "biodiversity",
    "forest",
    "conservancy",
    "wildfowl",
    "endangered species",
    "conservationists",
    "raptors",
    "birdlife",
    "wetlands",
    "otters",
    "spotted necked otter",
    "african clawless otter",
    "congo clawless otter",
    "eurasian otter",
    "fisheries",
    "waterbirds",
    "poachers",
    "bird sanctuary",
    "ecosystems",
    "reptiles",
    "naturalists",
    "marine",
    "waterways",
    "antelope",
    "wildflower",
    "ecotourism",
    "seabird",
    "turtles",
    "vegetation",
    "tortoises",
    "african spurred tortoise",
    "amphibians",
    "wolves",
    "stone curlew",
    "foxes",
    "sacred ibis",
    "african sacred ibis",
    "monarch butterfly",
    "african monarch butterfly",
    "plain tiger",
    "african monarch",
    "goshawk",
    "african goshawk",
    "cirl bunting",
    "leopards",
    "panther",
    "safari park",
    "seafowl",
    "bird of passage",
    "zoography",
    "zoological garden",
    "shore bird",
    "african black oystercatcher",
    "water thick-knee",
    "white-fronted plover",
    "blacksmith plover",
    "common sandpiper",
    "zoo",
    "mammal",
    "bird",
    "conservationist",
    "gallery forest",
    "zoographer",
    "wetland",
    "zoophagy",
    "bird table",
    "sea cow",
    "manatee",
    "tropical rain forest",
    "sea elephant",
    "elephant seal",
    "sea leopard",
    "aquatic bird",
    "birdwatch",
    "zoopathology",
    "wild dog",
    "african wild dog",
    "marine animal",
    "african elephant",
    "sanctuary",
    "miombo woodland",
    "woodland",
    "elephant bird",
    "birdling",
    "birdcatching",
    "rangership",
    "zoological",
    "wildgrave",
    "exotic",
    "indigenous",
    "aquatic",
    "terrestrial",
    "endangered",
    "migratory",
    "coastal",
    "captive",
    "vertebrate",
    "threatened",
    "fascinating",
    "nocturnal",
    "mammalian",
    "scenic",
    "endemic",
    "ocean",
    "underwater",
    "winged",
    "predatory",
    "fish",
    "plants",
    "forests",
    "forestry",
    "soil",
    "timber",
    "cattle",
    "insects",
    "soils",
    "wildlands",
    "wildflowers",
    "pesticides",
    "fishing",
    "extinction",
    "woods",
    "sanctuaries",
    "ecosystem",
    "elephants",
    "mammals",
    "outdoors",
    "ducks",
    "poaching",
    "harvesting",
    "watersheds",
    "decimation",
    "waterfalls",
    "forage",
    "invertebrates",
    "feeding",
    "extermination",
    "pastoralists",
    "shellfish",
    "whales",
    "buffalo",
    "african buffalo",
    "songbirds",
    "eagles",
    "seals",
    "squirrels",
    "hunted",
    "depleted",
    "inhabit",
    "exterminated",
    "forest ranger",
    "game warden",
    "gamekeeper",
    "park",
    "natural resources",
    "preservationist",
    "preserved",
    "safari",
    "serengeti",
    "agricultural",
    "biosphere",
    "environmental",
    "freshwater",
    "herbivores",
    "wildland",
    "pygmy hippopotamus",
    "ladybug",
    "golden eagle",
    "oranda goldfish",
    "oryxes",
    "cheetah",
    "rabbit",
    "scorpion",
    "crocodile",
    "critically endangered",
    "patas monkies",
    "mambas",
    "crocodiles",
    "comet moth",
    "bongos",
    "eagle",
    "white rhinoceroses",
    "madagascar cockroach",
    "dolphins",
    "eastern green mamba",
    "lizard",
    "night heron",
    "twig snake",
    "ostrich",
    "flycatcher",
    "vervet monkey",
    "northern white rhinoceros",
    "parrot",
    "shark",
    "angelshark",
    "olive baboon",
    "green bee eater",
    "flamingos",
    "bat",
    "shrimp",
    "fiddler crab",
    "doves",
    "jumping spider",
    "carpet viper",
    "horsefly",
    "jackson’s chameleon",
    "gorillas",
    "donkeys",
    "hyena",
    "mosquito",
    "sparrow",
    "macaque",
    "short-eared owl",
    "dragonfly",
    "chimps",
    "birds of prey",
    "suni",
    "cape buffalo",
    "mountain",
    "striped hyenas",
    "hyenas",
    "mountain gorilla",
    "striped hyena",
    "duck",
    "madagascar hissing cockroach",
    "african civet",
    "cuckoo",
    "nile crocodiles",
    "horned adder",
    "butterflies",
    "cape elephant shrew",
    "hippo",
    "moth",
    "guinea fowls",
    "geckos",
    "brown hyena",
    "shrew",
    "yellow cobra",
    "pigs",
    "warbler",
    "carpenter ant",
    "woodpecker",
    "wild boars",
    "chimpanzees",
    "snakes",
    "hammerheads",
    "liger",
    "extirpated",
    "bumblebee",
    "jellyfish",
    "oryx",
    "southeastern black rhino",
    "catfish",
    "peacock",
    "radiated tortoise",
    "lion",
    "cockroach",
    "elephant",
    "eurasian jay",
    "sardines",
    "wild cat",
    "cod",
    "springbok",
    "horses",
    "jackal",
    "sea eagle",
    "frog",
    "hyrax",
    "cross river gorilla",
    "heron",
    "hoopoe",
    "water buffalo",
    "common furniture beetle",
    "black rhino",
    "zebu",
    "scimitar-horned oryx",
    "hippos",
    "eel",
    "warthogs",
    "kingfishers",
    "african tree toad",
    "impala",
    "gerbils",
    "vinegaroon",
    "biscuit beetle",
    "insect",
    "wolf",
    "devil’s coach horse beetle",
    "lesser kudu",
    "gnat",
    "bush",
    "amphibian",
    "bird snake",
    "ring-tailed lemur",
    "leaf-tailed gecko",
    "huntsman spider",
    "bichir",
    "common wildebeest",
    "egyptian cobra",
    "egyptian asp",
    "linnet",
    "rhinoceroses",
    "zebras",
    "gazelles",
    "griffon vulture",
    "porcupine",
    "forest cobra",
    "egyptian tortoise",
    "spider ball python",
    "lions",
    "forest hog",
    "african penguin",
    "dusky shark",
    "barb",
    "mole snake",
    "madagascar jacana",
    "donkey",
    "termite",
    "chickens",
    "moorhen",
    "african grey parrot",
    "graylag goose",
    "red deer",
    "hippopotamuses",
    "wryneck",
    "lionfish",
    "leopard",
    "nile crocodile",
    "kudu",
    "tuna",
    "golden oriole",
    "stick insect",
    "aardvarks",
    "european polecat",
    "seal",
    "african bush elephant",
    "red kite",
    "grey mouse lemur",
    "snake",
    "false widow spider",
    "guinea fowl",
    "lechwe antelope",
    "crested crane",
    "blue whale",
    "impalas",
    "stork",
    "rat",
    "forest elephant",
    "puku",
    "civets",
    "bald eagle",
    "orb weaver",
    "mongoose",
    "vine snake",
    "baboon",
    "skink lizard",
    "king cobra",
    "sheep",
    "rats",
    "gerbil",
    "tortoise",
    "pheasant",
    "horned viper",
    "bat-eared fox",
    "silky shark",
    "dolphin",
    "dik-dik",
    "fossa",
    "tigers",
    "tiger beetle",
    "goat",
    "mamba",
    "chicken",
    "manta rays",
    "xerus",
    "camel",
    "sharks",
    "quail",
    "chimpanzee",
    "okapi",
    "senegal parrot",
    "marabou stork",
    "achrioptera manga",
    "brown bear",
    "desert rain frog",
    "monkey",
    "river turtle",
    "african wild dogs",
    "african palm civet",
    "rhinoceros",
    "african gray parrot",
    "stiletto snake",
    "african wild dogs",
    "bush viper",
    "fox",
    "caracals",
    "wild ass",
    "honey badger",
    "rhinos",
    "nigerian goat",
    "rock hyrax",
    "pangolin",
    "peregrine falcon",
    "crane",
    "vulnerable",
    "hippopotamus",
    "crow",
    "song thrush",
    "fire ball python",
    "dinopithecus",
    "electric catfish",
    "lappet-face vulture",
    "banana spider",
    "squirrel",
    "bush baby",
    "marlin",
    "hamadryas baboon",
    "nyala",
    "cat",
    "bushbaby",
    "galago",
    "woodlouse spider",
    "spotted hyena",
    "kestrel",
    "black widow",
    "satanic leaf-tailed gecko",
    "goldcrest",
    "patas",
    "scimitar oryx",
    "desert warthog",
    "barracuda",
    "grasshopper",
    "coton de tulear",
    "egyptian mau",
    "red spitting cobra",
    "camels",
    "hedgehog",
    "duiker",
    "bonobos",
    "housefly",
    "sand viper",
    "mozambique spitting cobra",
    "common hippos",
    "vultures",
    "goliath beetle",
    "porpoise",
    "vulture",
    "oribi",
    "hyraxes",
    "hamster",
    "black rhinoceros",
    "bearded vulture",
    "green bee-eater",
    "fennec fox",
    "gembsok oryx",
    "woodlouse",
    "buffaloes",
    "waterbuck",
    "dumeril’s boa",
    "indri",
    "brown dog tick",
    "black rhinoceroses",
    "common carp",
    "galapagos shark",
    "grant’s gazelle",
    "axanthic ball python",
    "bonobo",
    "fly",
    "buffalos",
    "fennec foxes",
    "african lion",
    "grey heron",
    "panthers",
    "rooster",
    "parakeet",
    "african golden cat",
    "otter",
    "worm",
    "lappet-faced vulture",
    "strawberry hermit crab",
    "redstart",
    "black widow spider",
    "wildebeest",
    "gnu",
    "lichtenstein’s hartebeest",
    "fruit bat",
    "burkina faso",
    "orange baboon tarantula",
    "patas monkey",
    "weasel",
    "termites",
    "cobra",
    "uromastyx",
    "spotted hyenas",
    "sea turtle",
    "agama lizard",
    "turaco",
    "horse",
    "egyptian vulture",
    "sea turtles",
    "giant african land snail",
    "wildebeest",
    "gnu",
    "mongooses",
    "parrots",
    "gorilla",
    "saturniidae moth",
    "sunset ball python",
    "flamingoes",
    "african buffalos",
    "flamingo",
    "addra gazelle",
    "thomson’s gazelle",
    "blind snake",
    "lavender albino ball python",
    "abyssinian",
    "goliath tigerfish",
    "lappet-faced vulture",
    "eastern lowland gorilla",
    "sable bull",
    "sable antelope",
    "goats",
    "european goldfinch",
    "warthog",
    "tick",
    "civet",
    "cichlid",
    "whinchat",
    "jacana",
    "banana cinnamon ball python",
    "bush elephant",
    "mouse",
    "western lowland gorillas",
    "eland",
    "giant ground pangolin",
    "brown-banded cockroach",
    "african elephants",
    "frogs",
    "wild dogs",
    "zonkey",
    "sei whale",
    "slug",
    "scorpions",
    "african jacana",
    "african bullfrog",
    "dugongs",
    "sand cat",
    "hawk moth caterpillar",
    "yellowfin tuna",
    "roan",
    "ibex",
    "madagascar tree boa",
    "african forest elephants",
    "orange dream ball python",
    "viper",
    "elephant shrew",
    "ethiopian wolf",
    "yellow mongoose",
    "bontebok",
    "aidi",
    "sperm whale",
    "kitefin shark",
    "eastern lowland gorillas",
    "tarantula hawk",
    "rodents",
    "white rhinoceros",
    "praying mantis",
    "monkeys",
    "meerkats",
    "gecko",
    "black panther",
    "grasshoppers",
    "minke whale",
    "coryphodon",
    "wildebeests",
    "cheetahs",
    "savannah elephants",
    "honey bee",
    "cicada",
    "eel catfish",
    "hedgehogs",
    "forest elephants",
    "white ferret",
    "albino ferrets",
    "bee-eater",
    "greater kudu",
    "cranes",
    "guinea fowl",
    "africanized bee",
    "killer bee",
    "mallard",
    "gerenuk",
    "waller’s gazelle",
    "kori bustard",
    "dwarf crocodile",
    "african lions",
    "fin whale",
    "pufferfish",
    "bongo",
    "manatees",
    "dormouse",
    "spiny bush viper",
    "tsetse fly",
    "glow worm",
    "bale mountain vervet",
    "vanga",
    "black rhinos",
    "sable antelope",
    "civets",
    "european robin",
    "chameleon",
    "rock python",
    "anteaters",
    "african bush elephants",
    "red fox",
    "owls",
    "peringuey’s adder",
    "bloodhound",
    "snail",
    "european bee-eater",
    "steinbok",
    "herons",
    "goliath frog",
    "fulvous whistling duck",
    "western lowland gorilla",
    "hornbill",
    "crab spider",
    "bed bugs",
    "spider wasp",
    "snouted cobra",
    "humpback whale",
    "avocets",
    "flea",
    "meerkat",
    "wildebeest",
    "myna bird",
    "african savanna elephant",
    "hare",
    "reedbuck",
    "chimpanzees",
    "the blue monkey",
    "gazelle",
    "shoebill stork",
    "woodpeckers",
    "caecilian",
    "pike",
    "dung beetle",
    "zebra",
    "codling moth",
    "beisa oryx",
    "brahminy blindsnake",
    "western gorilla",
    "african forest elephant",
    "bushbuck",
    "cape bushbuck",
    "basenji dog",
    "ant",
    "kudus",
    "mealybug",
    "deathwatch beetle",
    "yellow belly ball python",
    "sitatunga",
    "bale monkey",
    "aardvark",
    "aye-aye",
    "zebra spitting cobra",
    "humpback whales",
    "sable ferret",
    "african fish eagle",
    "rhino",
    "maggot",
    "no see ums",
    "no-see-ums",
    "hyenas",
    "leech",
    "bats",
    "eastern gorilla",
    "thrush",
    "klipspringer",
    "german cockroach",
    "common hippopotamus",
    "colobus monkey",
    "beetle",
    "fruit fly",
    "great dane",
    "nightingale",
    "bees",
    "magpie",
    "mantella frog",
    "sand crab",
    "american cockroach",
    "genet",
    "hognose snake",
    "spotted hyenas",
    "cricket",
    "willow warbler",
    "quelea quelea",
    "beetles",
    "nguni cattle",
    "invertebrate",
    "banana ball python",
    "falcon",
    "antelopes",
    "stingray",
    "earwig",
    "red-billed quelea bird",
    "lemur",
    "barn swallow",
    "african clawed frog",
    "zebra snake",
    "sulcata tortoise",
    "centipede",
    "pythons",
    "osprey",
    "african civets",
    "giraffe",
    "lungfish",
    "monitor lizard",
    "freeway ball python",
    "gaboon viper",
    "stallion",
    "robin",
    "lizards",
    "puss moth",
    "wasp",
    "lesser jacana",
    "mule",
    "mandrill",
    "zorse",
    "peafowls",
    "false cobra",
    "barn owl",
    "smokybrown cockroach",
    "moths",
    "shoebill",
    "whalehead",
    "whale-headed stork",
    "whalebill",
    "shoebill stork",
    "ostriches",
    "salmon",
    "crab",
    "bushpig",
    "mole cricket",
    "wolf spider",
    "baboons",
    "albacore tuna",
    "burchell’s zebra",
    "albatrosses",
    "barbary boar",
    "lemurs",
    "boomslang",
    "seahorse",
    "ortolan bunting",
    "gypsy moth",
    "topi",
    "jackals",
    "desert locust",
    "killer clown ball python",
    "blue monkey",
    "pelicans",
    "spitting cobra",
    "butterfly",
    "leopard tortoise",
    "brazilian treehopper",
    "grey-crowned crane",
    "portuguese man-of-war",
    "freshwater eel",
    "mayfly",
    "blister beetle",
    "madora moth",
    "firefly",
    "common house spider",
    "dog tick",
    "beecroft’s flying squirrels",
    "shrews",
    "black mamba",
    "armyworm",
    "owl",
    "grevy’s zebra",
    "hoopoes",
    "mole",
    "common raven",
    "ibis",
    "tree frog",
    "aardwolf",
    "extinct",
    "lobsters",
    "cape hyrax",
    "locust",
    "serval",
    "rhino viper",
    "caracal",
    "pigeon",
    "needlefish",
    "ground squirrel",
    "pangolins",
    "common buzzard",
    "ligers",
    "cow",
    "reptilian",
    "earthworm",
    "reptile",
    "green mamba",
    "kingfisher",
    "bee",
    "jerboas",
    "addax",
    "white rhino",
    "kenyan sand boa",
    "brookesia micra",
    "spotted hyaena",
    "boas",
    "aye aye",
    "naked mole rat",
    "millipede",
    "caterpillar",
    "senepol cattle",
    "devils coach horse beetle",
    "giraffes",
    "puff adder",
    "dragonflies",
    "glass lizard",
    "west african wild dog",
    "cows",
    "western green mamba",
    "lionfish",
    "cuckoos",
    "goliath frogs",
    "grysbok",
    "jerboa",
    "swan",
    "desert ghost ball python",
    "pelican",
  ];

conflictAndViolenceArray = [
    "violence",
    "conflict",
    "war",
    "atrocious",
    "atrocity",
    "crime",
    "violent",
    "weapon",
    "insurgency",
    "insurgent",
    "insurgence",
    "chaos",
    "chaotic",
    "arm",
    "terror",
    "flee",
    "militia",
    "outbreak",
    "crisis",
    "brutal",
    "collapse",
    "tension",
    "rebel",
    "genocide",
    "tension",
    "clash",
    "dead",
    "eruption",
    "criminal",
    "terrorism",
    "extremist",
    "abuse",
    "escalation",
    "escalate",
    "rape",
    "sanction",
    "corruption",
    "corrupt",
    "radical",
    "ban",
    "bomb",
    "blood",
    "cease-fire",
    "coup",
    "assault",
    "kidnap",
    "battle",
]

arrays = {'whitelistArray': whitelistArray, 'generalizationArray': generalizationArray,
          'tribalismArray': tribalismArray, 'natureArray': natureArray, 'conflictAndViolenceArray': conflictAndViolenceArray}
stem_arrays = {'whitelistArray': [], 'generalizationArray': [],
          'tribalismArray': [], 'natureArray': [], 'conflictAndViolenceArray': []}
arrays_length = {'whitelistArray': [], 'generalizationArray': [],
          'tribalismArray': [], 'natureArray': [], 'conflictAndViolenceArray': []}

# %%
# create stemmer
stemmer = SnowballStemmer(language='english')
for array_name in arrays.keys():
    # store length of arrays before stemming
    arrays_length[array_name].append('before:' + str(len(arrays[array_name])))
    
    for word in arrays[array_name]:
        stem_wrd = stemmer.stem(word)
        print(word + ' --> ' + stem_wrd)
        if stem_wrd not in stem_arrays[array_name]:
            stem_arrays[array_name].append(stem_wrd)
            
    # store length of arrays after stemming
    arrays_length[array_name].append('after:' + str(len(stem_arrays[array_name])))

# print stemmed arrays and the dict storing the lengths before and after stemming
print(stem_arrays)
# Out:
# pan-african --> pan-african
# pan african --> pan african
# african studies --> african studi
# african union --> african union
# south africa --> south africa
# west africa --> west africa
# north africa --> north africa
# east africa --> east africa
# southern africa --> southern africa
# northern africa --> northern africa
# eastern africa --> eastern africa
# western africa --> western africa
# african american --> african american
# africa --> africa
# subsaharan --> subsaharan
# continent --> contin
# sub-saharan --> sub-saharan
# ethnic --> ethnic
# nomadic --> nomad
# bushmen --> bushmen
# tribe --> tribe
# pygmy --> pygmi
# tribal --> tribal
# wildlife --> wildlif
# fauna --> fauna
# habitat --> habitat
# habitats --> habitat
# conservation --> conserv
# animals --> anim
# birds --> bird
# animal --> anim
# flora --> flora
# livestock --> livestock
# hunting --> hunt
# parks --> park
# biota --> biota
# geese --> gees
# egyptian geese --> egyptian gees
# egyptian goose --> egyptian goos
# goose --> goos
# wilderness --> wilder
# wild --> wild
# park --> park
# natural --> natur
# nature --> natur
# hunt --> hunt
# camping --> camp
# wildcat --> wildcat
# sauvage --> sauvag
# savage --> savag
# wild-type --> wild-typ
# waterfowl --> waterfowl
# deer --> deer
# barbary stag --> barbary stag
# ecology --> ecolog
# biodiversity --> biodivers
# forest --> forest
# conservancy --> conserv
# wildfowl --> wildfowl
# endangered species --> endangered speci
# conservationists --> conservationist
# raptors --> raptor
# birdlife --> birdlif
# wetlands --> wetland
# otters --> otter
# spotted necked otter --> spotted necked ott
# african clawless otter --> african clawless ott
# congo clawless otter --> congo clawless ott
# eurasian otter --> eurasian ott
# fisheries --> fisheri
# waterbirds --> waterbird
# poachers --> poacher
# bird sanctuary --> bird sanctuari
# ecosystems --> ecosystem
# reptiles --> reptil
# naturalists --> naturalist
# marine --> marin
# waterways --> waterway
# antelope --> antelop
# wildflower --> wildflow
# ecotourism --> ecotour
# seabird --> seabird
# turtles --> turtl
# vegetation --> veget
# tortoises --> tortois
# african spurred tortoise --> african spurred tortois
# amphibians --> amphibian
# wolves --> wolv
# stone curlew --> stone curlew
# foxes --> fox
# sacred ibis --> sacred ibi
# african sacred ibis --> african sacred ibi
# monarch butterfly --> monarch butterfli
# african monarch butterfly --> african monarch butterfli
# plain tiger --> plain tig
# african monarch --> african monarch
# goshawk --> goshawk
# african goshawk --> african goshawk
# cirl bunting --> cirl bunt
# leopards --> leopard
# panther --> panther
# safari park --> safari park
# seafowl --> seafowl
# bird of passage --> bird of passag
# zoography --> zoographi
# zoological garden --> zoological garden
# shore bird --> shore bird
# african black oystercatcher --> african black oystercatch
# water thick-knee --> water thick-kne
# white-fronted plover --> white-fronted plov
# blacksmith plover --> blacksmith plov
# common sandpiper --> common sandpip
# zoo --> zoo
# mammal --> mammal
# bird --> bird
# conservationist --> conservationist
# gallery forest --> gallery forest
# zoographer --> zoograph
# wetland --> wetland
# zoophagy --> zoophagi
# bird table --> bird tabl
# sea cow --> sea cow
# manatee --> manate
# tropical rain forest --> tropical rain forest
# sea elephant --> sea eleph
# elephant seal --> elephant s
# sea leopard --> sea leopard
# aquatic bird --> aquatic bird
# birdwatch --> birdwatch
# zoopathology --> zoopatholog
# wild dog --> wild dog
# african wild dog --> african wild dog
# marine animal --> marine anim
# african elephant --> african eleph
# sanctuary --> sanctuari
# miombo woodland --> miombo woodland
# woodland --> woodland
# elephant bird --> elephant bird
# birdling --> birdl
# birdcatching --> birdcatch
# rangership --> rangership
# zoological --> zoolog
# wildgrave --> wildgrav
# exotic --> exot
# indigenous --> indigen
# aquatic --> aquat
# terrestrial --> terrestri
# endangered --> endang
# migratory --> migratori
# coastal --> coastal
# captive --> captiv
# vertebrate --> vertebr
# threatened --> threaten
# fascinating --> fascin
# nocturnal --> nocturn
# mammalian --> mammalian
# scenic --> scenic
# endemic --> endem
# ocean --> ocean
# underwater --> underwat
# winged --> wing
# predatory --> predatori
# fish --> fish
# plants --> plant
# forests --> forest
# forestry --> forestri
# soil --> soil
# timber --> timber
# cattle --> cattl
# insects --> insect
# soils --> soil
# wildlands --> wildland
# wildflowers --> wildflow
# pesticides --> pesticid
# fishing --> fish
# extinction --> extinct
# woods --> wood
# sanctuaries --> sanctuari
# ecosystem --> ecosystem
# elephants --> eleph
# mammals --> mammal
# outdoors --> outdoor
# ducks --> duck
# poaching --> poach
# harvesting --> harvest
# watersheds --> watersh
# decimation --> decim
# waterfalls --> waterfal
# forage --> forag
# invertebrates --> invertebr
# feeding --> feed
# extermination --> extermin
# pastoralists --> pastoralist
# shellfish --> shellfish
# whales --> whale
# buffalo --> buffalo
# african buffalo --> african buffalo
# songbirds --> songbird
# eagles --> eagl
# seals --> seal
# squirrels --> squirrel
# hunted --> hunt
# depleted --> deplet
# inhabit --> inhabit
# exterminated --> extermin
# forest ranger --> forest rang
# game warden --> game warden
# gamekeeper --> gamekeep
# park --> park
# natural resources --> natural resourc
# preservationist --> preservationist
# preserved --> preserv
# safari --> safari
# serengeti --> serengeti
# agricultural --> agricultur
# biosphere --> biospher
# environmental --> environment
# freshwater --> freshwat
# herbivores --> herbivor
# wildland --> wildland
# pygmy hippopotamus --> pygmy hippopotamus
# ladybug --> ladybug
# golden eagle --> golden eagl
# oranda goldfish --> oranda goldfish
# oryxes --> oryx
# cheetah --> cheetah
# rabbit --> rabbit
# scorpion --> scorpion
# crocodile --> crocodil
# critically endangered --> critically endang
# patas monkies --> patas monki
# mambas --> mamba
# crocodiles --> crocodil
# comet moth --> comet moth
# bongos --> bongo
# eagle --> eagl
# white rhinoceroses --> white rhinoceros
# madagascar cockroach --> madagascar cockroach
# dolphins --> dolphin
# eastern green mamba --> eastern green mamba
# lizard --> lizard
# night heron --> night heron
# twig snake --> twig snak
# ostrich --> ostrich
# flycatcher --> flycatch
# vervet monkey --> vervet monkey
# northern white rhinoceros --> northern white rhinocero
# parrot --> parrot
# shark --> shark
# angelshark --> angelshark
# olive baboon --> olive baboon
# green bee eater --> green bee eat
# flamingos --> flamingo
# bat --> bat
# shrimp --> shrimp
# fiddler crab --> fiddler crab
# doves --> dove
# jumping spider --> jumping spid
# carpet viper --> carpet vip
# horsefly --> horsefli
# jackson’s chameleon --> jackson's chameleon
# gorillas --> gorilla
# donkeys --> donkey
# hyena --> hyena
# mosquito --> mosquito
# sparrow --> sparrow
# macaque --> macaqu
# short-eared owl --> short-eared owl
# dragonfly --> dragonfli
# chimps --> chimp
# birds of prey --> birds of prey
# suni --> suni
# cape buffalo --> cape buffalo
# mountain --> mountain
# striped hyenas --> striped hyena
# hyenas --> hyena
# mountain gorilla --> mountain gorilla
# striped hyena --> striped hyena
# duck --> duck
# madagascar hissing cockroach --> madagascar hissing cockroach
# african civet --> african civet
# cuckoo --> cuckoo
# nile crocodiles --> nile crocodil
# horned adder --> horned add
# butterflies --> butterfli
# cape elephant shrew --> cape elephant shrew
# hippo --> hippo
# moth --> moth
# guinea fowls --> guinea fowl
# geckos --> gecko
# brown hyena --> brown hyena
# shrew --> shrew
# yellow cobra --> yellow cobra
# pigs --> pig
# warbler --> warbler
# carpenter ant --> carpenter
# woodpecker --> woodpeck
# wild boars --> wild boar
# chimpanzees --> chimpanze
# snakes --> snake
# hammerheads --> hammerhead
# liger --> liger
# extirpated --> extirp
# bumblebee --> bumblebe
# jellyfish --> jellyfish
# oryx --> oryx
# southeastern black rhino --> southeastern black rhino
# catfish --> catfish
# peacock --> peacock
# radiated tortoise --> radiated tortois
# lion --> lion
# cockroach --> cockroach
# elephant --> eleph
# eurasian jay --> eurasian jay
# sardines --> sardin
# wild cat --> wild cat
# cod --> cod
# springbok --> springbok
# horses --> hors
# jackal --> jackal
# sea eagle --> sea eagl
# frog --> frog
# hyrax --> hyrax
# cross river gorilla --> cross river gorilla
# heron --> heron
# hoopoe --> hoopo
# water buffalo --> water buffalo
# common furniture beetle --> common furniture beetl
# black rhino --> black rhino
# zebu --> zebu
# scimitar-horned oryx --> scimitar-horned oryx
# hippos --> hippo
# eel --> eel
# warthogs --> warthog
# kingfishers --> kingfish
# african tree toad --> african tree toad
# impala --> impala
# gerbils --> gerbil
# vinegaroon --> vinegaroon
# biscuit beetle --> biscuit beetl
# insect --> insect
# wolf --> wolf
# devil’s coach horse beetle --> devil's coach horse beetl
# lesser kudu --> lesser kudu
# gnat --> gnat
# bush --> bush
# amphibian --> amphibian
# bird snake --> bird snak
# ring-tailed lemur --> ring-tailed lemur
# leaf-tailed gecko --> leaf-tailed gecko
# huntsman spider --> huntsman spid
# bichir --> bichir
# common wildebeest --> common wildebeest
# egyptian cobra --> egyptian cobra
# egyptian asp --> egyptian asp
# linnet --> linnet
# rhinoceroses --> rhinoceros
# zebras --> zebra
# gazelles --> gazell
# griffon vulture --> griffon vultur
# porcupine --> porcupin
# forest cobra --> forest cobra
# egyptian tortoise --> egyptian tortois
# spider ball python --> spider ball python
# lions --> lion
# forest hog --> forest hog
# african penguin --> african penguin
# dusky shark --> dusky shark
# barb --> barb
# mole snake --> mole snak
# madagascar jacana --> madagascar jacana
# donkey --> donkey
# termite --> termit
# chickens --> chicken
# moorhen --> moorhen
# african grey parrot --> african grey parrot
# graylag goose --> graylag goos
# red deer --> red deer
# hippopotamuses --> hippopotamus
# wryneck --> wryneck
# lionfish --> lionfish
# leopard --> leopard
# nile crocodile --> nile crocodil
# kudu --> kudu
# tuna --> tuna
# golden oriole --> golden oriol
# stick insect --> stick insect
# aardvarks --> aardvark
# european polecat --> european polecat
# seal --> seal
# african bush elephant --> african bush eleph
# red kite --> red kit
# grey mouse lemur --> grey mouse lemur
# snake --> snake
# false widow spider --> false widow spid
# guinea fowl --> guinea fowl
# lechwe antelope --> lechwe antelop
# crested crane --> crested cran
# blue whale --> blue whal
# impalas --> impala
# stork --> stork
# rat --> rat
# forest elephant --> forest eleph
# puku --> puku
# civets --> civet
# bald eagle --> bald eagl
# orb weaver --> orb weav
# mongoose --> mongoos
# vine snake --> vine snak
# baboon --> baboon
# skink lizard --> skink lizard
# king cobra --> king cobra
# sheep --> sheep
# rats --> rat
# gerbil --> gerbil
# tortoise --> tortois
# pheasant --> pheasant
# horned viper --> horned vip
# bat-eared fox --> bat-eared fox
# silky shark --> silky shark
# dolphin --> dolphin
# dik-dik --> dik-dik
# fossa --> fossa
# tigers --> tiger
# tiger beetle --> tiger beetl
# goat --> goat
# mamba --> mamba
# chicken --> chicken
# manta rays --> manta ray
# xerus --> xerus
# camel --> camel
# sharks --> shark
# quail --> quail
# chimpanzee --> chimpanze
# okapi --> okapi
# senegal parrot --> senegal parrot
# marabou stork --> marabou stork
# achrioptera manga --> achrioptera manga
# brown bear --> brown bear
# desert rain frog --> desert rain frog
# monkey --> monkey
# river turtle --> river turtl
# african wild dogs --> african wild dog
# african palm civet --> african palm civet
# rhinoceros --> rhinocero
# african gray parrot --> african gray parrot
# stiletto snake --> stiletto snak
# african wild dogs --> african wild dog
# bush viper --> bush vip
# fox --> fox
# caracals --> carac
# wild ass --> wild ass
# honey badger --> honey badg
# rhinos --> rhino
# nigerian goat --> nigerian goat
# rock hyrax --> rock hyrax
# pangolin --> pangolin
# peregrine falcon --> peregrine falcon
# crane --> crane
# vulnerable --> vulner
# hippopotamus --> hippopotamus
# crow --> crow
# song thrush --> song thrush
# fire ball python --> fire ball python
# dinopithecus --> dinopithecus
# electric catfish --> electric catfish
# lappet-face vulture --> lappet-face vultur
# banana spider --> banana spid
# squirrel --> squirrel
# bush baby --> bush babi
# marlin --> marlin
# hamadryas baboon --> hamadryas baboon
# nyala --> nyala
# cat --> cat
# bushbaby --> bushbabi
# galago --> galago
# woodlouse spider --> woodlouse spid
# spotted hyena --> spotted hyena
# kestrel --> kestrel
# black widow --> black widow
# satanic leaf-tailed gecko --> satanic leaf-tailed gecko
# goldcrest --> goldcrest
# patas --> pata
# scimitar oryx --> scimitar oryx
# desert warthog --> desert warthog
# barracuda --> barracuda
# grasshopper --> grasshopp
# coton de tulear --> coton de tulear
# egyptian mau --> egyptian mau
# red spitting cobra --> red spitting cobra
# camels --> camel
# hedgehog --> hedgehog
# duiker --> duiker
# bonobos --> bonobo
# housefly --> housefli
# sand viper --> sand vip
# mozambique spitting cobra --> mozambique spitting cobra
# common hippos --> common hippo
# vultures --> vultur
# goliath beetle --> goliath beetl
# porpoise --> porpois
# vulture --> vultur
# oribi --> oribi
# hyraxes --> hyrax
# hamster --> hamster
# black rhinoceros --> black rhinocero
# bearded vulture --> bearded vultur
# green bee-eater --> green bee-eat
# fennec fox --> fennec fox
# gembsok oryx --> gembsok oryx
# woodlouse --> woodlous
# buffaloes --> buffalo
# waterbuck --> waterbuck
# dumeril’s boa --> dumeril's boa
# indri --> indri
# brown dog tick --> brown dog tick
# black rhinoceroses --> black rhinoceros
# common carp --> common carp
# galapagos shark --> galapagos shark
# grant’s gazelle --> grant's gazell
# axanthic ball python --> axanthic ball python
# bonobo --> bonobo
# fly --> fli
# buffalos --> buffalo
# fennec foxes --> fennec fox
# african lion --> african lion
# grey heron --> grey heron
# panthers --> panther
# rooster --> rooster
# parakeet --> parakeet
# african golden cat --> african golden cat
# otter --> otter
# worm --> worm
# lappet-faced vulture --> lappet-faced vultur
# strawberry hermit crab --> strawberry hermit crab
# redstart --> redstart
# black widow spider --> black widow spid
# wildebeest --> wildebeest
# gnu --> gnu
# lichtenstein’s hartebeest --> lichtenstein's hartebeest
# fruit bat --> fruit bat
# burkina faso --> burkina faso
# orange baboon tarantula --> orange baboon tarantula
# patas monkey --> patas monkey
# weasel --> weasel
# termites --> termit
# cobra --> cobra
# uromastyx --> uromastyx
# spotted hyenas --> spotted hyena
# sea turtle --> sea turtl
# agama lizard --> agama lizard
# turaco --> turaco
# horse --> hors
# egyptian vulture --> egyptian vultur
# sea turtles --> sea turtl
# giant african land snail --> giant african land snail
# wildebeest --> wildebeest
# gnu --> gnu
# mongooses --> mongoos
# parrots --> parrot
# gorilla --> gorilla
# saturniidae moth --> saturniidae moth
# sunset ball python --> sunset ball python
# flamingoes --> flamingo
# african buffalos --> african buffalo
# flamingo --> flamingo
# addra gazelle --> addra gazell
# thomson’s gazelle --> thomson's gazell
# blind snake --> blind snak
# lavender albino ball python --> lavender albino ball python
# abyssinian --> abyssinian
# goliath tigerfish --> goliath tigerfish
# lappet-faced vulture --> lappet-faced vultur
# eastern lowland gorilla --> eastern lowland gorilla
# sable bull --> sable bul
# sable antelope --> sable antelop
# goats --> goat
# european goldfinch --> european goldfinch
# warthog --> warthog
# tick --> tick
# civet --> civet
# cichlid --> cichlid
# whinchat --> whinchat
# jacana --> jacana
# banana cinnamon ball python --> banana cinnamon ball python
# bush elephant --> bush eleph
# mouse --> mous
# western lowland gorillas --> western lowland gorilla
# eland --> eland
# giant ground pangolin --> giant ground pangolin
# brown-banded cockroach --> brown-banded cockroach
# african elephants --> african eleph
# frogs --> frog
# wild dogs --> wild dog
# zonkey --> zonkey
# sei whale --> sei whal
# slug --> slug
# scorpions --> scorpion
# african jacana --> african jacana
# african bullfrog --> african bullfrog
# dugongs --> dugong
# sand cat --> sand cat
# hawk moth caterpillar --> hawk moth caterpillar
# yellowfin tuna --> yellowfin tuna
# roan --> roan
# ibex --> ibex
# madagascar tree boa --> madagascar tree boa
# african forest elephants --> african forest eleph
# orange dream ball python --> orange dream ball python
# viper --> viper
# elephant shrew --> elephant shrew
# ethiopian wolf --> ethiopian wolf
# yellow mongoose --> yellow mongoos
# bontebok --> bontebok
# aidi --> aidi
# sperm whale --> sperm whal
# kitefin shark --> kitefin shark
# eastern lowland gorillas --> eastern lowland gorilla
# tarantula hawk --> tarantula hawk
# rodents --> rodent
# white rhinoceros --> white rhinocero
# praying mantis --> praying manti
# monkeys --> monkey
# meerkats --> meerkat
# gecko --> gecko
# black panther --> black panth
# grasshoppers --> grasshopp
# minke whale --> minke whal
# coryphodon --> coryphodon
# wildebeests --> wildebeest
# cheetahs --> cheetah
# savannah elephants --> savannah eleph
# honey bee --> honey be
# cicada --> cicada
# eel catfish --> eel catfish
# hedgehogs --> hedgehog
# forest elephants --> forest eleph
# white ferret --> white ferret
# albino ferrets --> albino ferret
# bee-eater --> bee-eat
# greater kudu --> greater kudu
# cranes --> crane
# guinea fowl --> guinea fowl
# africanized bee --> africanized be
# killer bee --> killer be
# mallard --> mallard
# gerenuk --> gerenuk
# waller’s gazelle --> waller's gazell
# kori bustard --> kori bustard
# dwarf crocodile --> dwarf crocodil
# african lions --> african lion
# fin whale --> fin whal
# pufferfish --> pufferfish
# bongo --> bongo
# manatees --> manate
# dormouse --> dormous
# spiny bush viper --> spiny bush vip
# tsetse fly --> tsetse fli
# glow worm --> glow worm
# bale mountain vervet --> bale mountain vervet
# vanga --> vanga
# black rhinos --> black rhino
# sable antelope --> sable antelop
# civets --> civet
# european robin --> european robin
# chameleon --> chameleon
# rock python --> rock python
# anteaters --> anteat
# african bush elephants --> african bush eleph
# red fox --> red fox
# owls --> owl
# peringuey’s adder --> peringuey's add
# bloodhound --> bloodhound
# snail --> snail
# european bee-eater --> european bee-eat
# steinbok --> steinbok
# herons --> heron
# goliath frog --> goliath frog
# fulvous whistling duck --> fulvous whistling duck
# western lowland gorilla --> western lowland gorilla
# hornbill --> hornbil
# crab spider --> crab spid
# bed bugs --> bed bug
# spider wasp --> spider wasp
# snouted cobra --> snouted cobra
# humpback whale --> humpback whal
# avocets --> avocet
# flea --> flea
# meerkat --> meerkat
# wildebeest --> wildebeest
# myna bird --> myna bird
# african savanna elephant --> african savanna eleph
# hare --> hare
# reedbuck --> reedbuck
# chimpanzees --> chimpanze
# the blue monkey --> the blue monkey
# gazelle --> gazell
# shoebill stork --> shoebill stork
# woodpeckers --> woodpeck
# caecilian --> caecilian
# pike --> pike
# dung beetle --> dung beetl
# zebra --> zebra
# codling moth --> codling moth
# beisa oryx --> beisa oryx
# brahminy blindsnake --> brahminy blindsnak
# western gorilla --> western gorilla
# african forest elephant --> african forest eleph
# bushbuck --> bushbuck
# cape bushbuck --> cape bushbuck
# basenji dog --> basenji dog
# ant --> ant
# kudus --> kudus
# mealybug --> mealybug
# deathwatch beetle --> deathwatch beetl
# yellow belly ball python --> yellow belly ball python
# sitatunga --> sitatunga
# bale monkey --> bale monkey
# aardvark --> aardvark
# aye-aye --> aye-ay
# zebra spitting cobra --> zebra spitting cobra
# humpback whales --> humpback whal
# sable ferret --> sable ferret
# african fish eagle --> african fish eagl
# rhino --> rhino
# maggot --> maggot
# no see ums --> no see um
# no-see-ums --> no-see-um
# hyenas --> hyena
# leech --> leech
# bats --> bat
# eastern gorilla --> eastern gorilla
# thrush --> thrush
# klipspringer --> klipspring
# german cockroach --> german cockroach
# common hippopotamus --> common hippopotamus
# colobus monkey --> colobus monkey
# beetle --> beetl
# fruit fly --> fruit fli
# great dane --> great dan
# nightingale --> nightingal
# bees --> bee
# magpie --> magpi
# mantella frog --> mantella frog
# sand crab --> sand crab
# american cockroach --> american cockroach
# genet --> genet
# hognose snake --> hognose snak
# spotted hyenas --> spotted hyena
# cricket --> cricket
# willow warbler --> willow warbl
# quelea quelea --> quelea quelea
# beetles --> beetl
# nguni cattle --> nguni cattl
# invertebrate --> invertebr
# banana ball python --> banana ball python
# falcon --> falcon
# antelopes --> antelop
# stingray --> stingray
# earwig --> earwig
# red-billed quelea bird --> red-billed quelea bird
# lemur --> lemur
# barn swallow --> barn swallow
# african clawed frog --> african clawed frog
# zebra snake --> zebra snak
# sulcata tortoise --> sulcata tortois
# centipede --> centiped
# pythons --> python
# osprey --> osprey
# african civets --> african civet
# giraffe --> giraff
# lungfish --> lungfish
# monitor lizard --> monitor lizard
# freeway ball python --> freeway ball python
# gaboon viper --> gaboon vip
# stallion --> stallion
# robin --> robin
# lizards --> lizard
# puss moth --> puss moth
# wasp --> wasp
# lesser jacana --> lesser jacana
# mule --> mule
# mandrill --> mandril
# zorse --> zors
# peafowls --> peafowl
# false cobra --> false cobra
# barn owl --> barn owl
# smokybrown cockroach --> smokybrown cockroach
# moths --> moth
# shoebill --> shoebil
# whalehead --> whalehead
# whale-headed stork --> whale-headed stork
# whalebill --> whalebil
# shoebill stork --> shoebill stork
# ostriches --> ostrich
# salmon --> salmon
# crab --> crab
# bushpig --> bushpig
# mole cricket --> mole cricket
# wolf spider --> wolf spid
# baboons --> baboon
# albacore tuna --> albacore tuna
# burchell’s zebra --> burchell's zebra
# albatrosses --> albatross
# barbary boar --> barbary boar
# lemurs --> lemur
# boomslang --> boomslang
# seahorse --> seahors
# ortolan bunting --> ortolan bunt
# gypsy moth --> gypsy moth
# topi --> topi
# jackals --> jackal
# desert locust --> desert locust
# killer clown ball python --> killer clown ball python
# blue monkey --> blue monkey
# pelicans --> pelican
# spitting cobra --> spitting cobra
# butterfly --> butterfli
# leopard tortoise --> leopard tortois
# brazilian treehopper --> brazilian treehopp
# grey-crowned crane --> grey-crowned cran
# portuguese man-of-war --> portuguese man-of-war
# freshwater eel --> freshwater eel
# mayfly --> mayfli
# blister beetle --> blister beetl
# madora moth --> madora moth
# firefly --> firefli
# common house spider --> common house spid
# dog tick --> dog tick
# beecroft’s flying squirrels --> beecroft's flying squirrel
# shrews --> shrew
# black mamba --> black mamba
# armyworm --> armyworm
# owl --> owl
# grevy’s zebra --> grevy's zebra
# hoopoes --> hoopo
# mole --> mole
# common raven --> common raven
# ibis --> ibi
# tree frog --> tree frog
# aardwolf --> aardwolf
# extinct --> extinct
# lobsters --> lobster
# cape hyrax --> cape hyrax
# locust --> locust
# serval --> serval
# rhino viper --> rhino vip
# caracal --> carac
# pigeon --> pigeon
# needlefish --> needlefish
# ground squirrel --> ground squirrel
# pangolins --> pangolin
# common buzzard --> common buzzard
# ligers --> liger
# cow --> cow
# reptilian --> reptilian
# earthworm --> earthworm
# reptile --> reptil
# green mamba --> green mamba
# kingfisher --> kingfish
# bee --> bee
# jerboas --> jerboa
# addax --> addax
# white rhino --> white rhino
# kenyan sand boa --> kenyan sand boa
# brookesia micra --> brookesia micra
# spotted hyaena --> spotted hyaena
# boas --> boa
# aye aye --> aye ay
# naked mole rat --> naked mole rat
# millipede --> milliped
# caterpillar --> caterpillar
# senepol cattle --> senepol cattl
# devils coach horse beetle --> devils coach horse beetl
# giraffes --> giraff
# puff adder --> puff add
# dragonflies --> dragonfli
# glass lizard --> glass lizard
# west african wild dog --> west african wild dog
# cows --> cow
# western green mamba --> western green mamba
# lionfish --> lionfish
# cuckoos --> cuckoo
# goliath frogs --> goliath frog
# grysbok --> grysbok
# jerboa --> jerboa
# swan --> swan
# desert ghost ball python --> desert ghost ball python
# pelican --> pelican
# violence --> violenc
# conflict --> conflict
# war --> war
# atrocious --> atroci
# atrocity --> atroc
# crime --> crime
# violent --> violent
# weapon --> weapon
# insurgency --> insurg
# insurgent --> insurg
# insurgence --> insurg
# chaos --> chao
# chaotic --> chaotic
# arm --> arm
# terror --> terror
# flee --> flee
# militia --> militia
# outbreak --> outbreak
# crisis --> crisi
# brutal --> brutal
# collapse --> collaps
# tension --> tension
# rebel --> rebel
# genocide --> genocid
# tension --> tension
# clash --> clash
# dead --> dead
# eruption --> erupt
# criminal --> crimin
# terrorism --> terror
# extremist --> extremist
# abuse --> abus
# escalation --> escal
# escalate --> escal
# rape --> rape
# sanction --> sanction
# corruption --> corrupt
# corrupt --> corrupt
# radical --> radic
# ban --> ban
# bomb --> bomb
# blood --> blood
# cease-fire --> cease-fir
# coup --> coup
# assault --> assault
# kidnap --> kidnap
# battle --> battl
# {'whitelistArray': ['pan-african', 'pan african', 'african studi', 'african union', 'south africa', 'west africa', 'north africa', 'east africa', 'southern africa', 'northern africa', 'eastern africa', 'western africa', 'african american'], 'generalizationArray': ['africa', 'subsaharan', 'contin', 'sub-saharan'], 'tribalismArray': ['ethnic', 'nomad', 'bushmen', 'tribe', 'pygmi', 'tribal'], 'natureArray': ['wildlif', 'fauna', 'habitat', 'conserv', 'anim', 'bird', 'flora', 'livestock', 'hunt', 'park', 'biota', 'gees', 'egyptian gees', 'egyptian goos', 'goos', 'wilder', 'wild', 'natur', 'camp', 'wildcat', 'sauvag', 'savag', 'wild-typ', 'waterfowl', 'deer', 'barbary stag', 'ecolog', 'biodivers', 'forest', 'wildfowl', 'endangered speci', 'conservationist', 'raptor', 'birdlif', 'wetland', 'otter', 'spotted necked ott', 'african clawless ott', 'congo clawless ott', 'eurasian ott', 'fisheri', 'waterbird', 'poacher', 'bird sanctuari', 'ecosystem', 'reptil', 'naturalist', 'marin', 'waterway', 'antelop', 'wildflow', 'ecotour', 'seabird', 'turtl', 'veget', 'tortois', 'african spurred tortois', 'amphibian', 'wolv', 'stone curlew', 'fox', 'sacred ibi', 'african sacred ibi', 'monarch butterfli', 'african monarch butterfli', 'plain tig', 'african monarch', 'goshawk', 'african goshawk', 'cirl bunt', 'leopard', 'panther', 'safari park', 'seafowl', 'bird of passag', 'zoographi', 'zoological garden', 'shore bird', 'african black oystercatch', 'water thick-kne', 'white-fronted plov', 'blacksmith plov', 'common sandpip', 'zoo', 'mammal', 'gallery forest', 'zoograph', 'zoophagi', 'bird tabl', 'sea cow', 'manate', 'tropical rain forest', 'sea eleph', 'elephant s', 'sea leopard', 'aquatic bird', 'birdwatch', 'zoopatholog', 'wild dog', 'african wild dog', 'marine anim', 'african eleph', 'sanctuari', 'miombo woodland', 'woodland', 'elephant bird', 'birdl', 'birdcatch', 'rangership', 'zoolog', 'wildgrav', 'exot', 'indigen', 'aquat', 'terrestri', 'endang', 'migratori', 'coastal', 'captiv', 'vertebr', 'threaten', 'fascin', 'nocturn', 'mammalian', 'scenic', 'endem', 'ocean', 'underwat', 'wing', 'predatori', 'fish', 'plant', 'forestri', 'soil', 'timber', 'cattl', 'insect', 'wildland', 'pesticid', 'extinct', 'wood', 'eleph', 'outdoor', 'duck', 'poach', 'harvest', 'watersh', 'decim', 'waterfal', 'forag', 'invertebr', 'feed', 'extermin', 'pastoralist', 'shellfish', 'whale', 'buffalo', 'african buffalo', 'songbird', 'eagl', 'seal', 'squirrel', 'deplet', 'inhabit', 'forest rang', 'game warden', 'gamekeep', 'natural resourc', 'preservationist', 'preserv', 'safari', 'serengeti', 'agricultur', 'biospher', 'environment', 'freshwat', 'herbivor', 'pygmy hippopotamus', 'ladybug', 'golden eagl', 'oranda goldfish', 'oryx', 'cheetah', 'rabbit', 'scorpion', 'crocodil', 'critically endang', 'patas monki', 'mamba', 'comet moth', 'bongo', 'white rhinoceros', 'madagascar cockroach', 'dolphin', 'eastern green mamba', 'lizard', 'night heron', 'twig snak', 'ostrich', 'flycatch', 'vervet monkey', 'northern white rhinocero', 'parrot', 'shark', 'angelshark', 'olive baboon', 'green bee eat', 'flamingo', 'bat', 'shrimp', 'fiddler crab', 'dove', 'jumping spid', 'carpet vip', 'horsefli', "jackson's chameleon", 'gorilla', 'donkey', 'hyena', 'mosquito', 'sparrow', 'macaqu', 'short-eared owl', 'dragonfli', 'chimp', 'birds of prey', 'suni', 'cape buffalo', 'mountain', 'striped hyena', 'mountain gorilla', 'madagascar hissing cockroach', 'african civet', 'cuckoo', 'nile crocodil', 'horned add', 'butterfli', 'cape elephant shrew', 'hippo', 'moth', 'guinea fowl', 'gecko', 'brown hyena', 'shrew', 'yellow cobra', 'pig', 'warbler', 'carpenter ', 'woodpeck', 'wild boar', 'chimpanze', 'snake', 'hammerhead', 'liger', 'extirp', 'bumblebe', 'jellyfish', 'southeastern black rhino', 'catfish', 'peacock', 'radiated tortois', 'lion', 'cockroach', 'eurasian jay', 'sardin', 'wild cat', 'cod', 'springbok', 'hors', 'jackal', 'sea eagl', 'frog', 'hyrax', 'cross river gorilla', 'heron', 'hoopo', 'water buffalo',  ...

# %%
print(arrays_length)
# Out:
# {'whitelistArray': ['before13', 'before:13', 'after:13', 'before:13', 'after:13', 'before:13', 'after:13'], 'generalizationArray': ['before:4', 'after:4', 'before:4', 'after:4', 'before:4', 'after:4'], 'tribalismArray': ['before:6', 'after:6', 'before:6', 'after:6', 'before:6', 'after:6'], 'natureArray': ['before:866', 'after:724', 'before:866', 'after:724', 'before:866', 'after:724'], 'conflictAndViolenceArray': ['before:47', 'after:41', 'before:47', 'after:41', 'before:47', 'after:41']}
