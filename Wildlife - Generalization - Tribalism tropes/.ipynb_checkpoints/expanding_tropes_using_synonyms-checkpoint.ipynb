# %% [markdown]
# ## Introduction
#
# This notebook is designed to expand words under the existing four tropes by adding their synonyms.

# %% [markdown]
# #### Step 1: Import Packages
#
# We will access Princeton University's wordnet through the spacy package since spacy has a user friendly interface. Note, wordnet can be accessed through the nltk package as well.

# %%
import spacy
from spacy_wordnet.wordnet_annotator import WordnetAnnotator

# %% [markdown]
# #### Step 2: Initialize spaCy Model
#
# Start by initializing a spacy model. This model is trained for the English language, (represented by `_en`). It provides the core operations: vocabulary, syntax, entities, and vectors (represented by the `_core` flag). It is trained using blogs, news, comments etc text from the web (represented by the `_web` flag). And, it is the largest size available containing all the functionalities needed for this project (represented by the `_lg` flag). Check [this link](https://spacy.io/models/en) for more documentation.

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# #### Step 3: Load Wordnet
#
# Although spacy has numerous functionalities, we want to use the added package `WordNet` for this specific portion of the project. For this portion, we are interested in finding synonyms to the words under different tropes for the ASTRSC website. WordNet is the most suited database for this task. Developed by Princeton University,
#
# "**WordNet is a large lexical database of English**. Nouns, verbs, adjectives and adverbs are grouped into sets of cognitive synonyms (synsets), each expressing a distinct concept....**WordNet superficially resembles a thesaurus, in that it groups words together based on their meanings.** " Check [the website](https://wordnet.princeton.edu/) for more detail.
#
# Users of WordNet describe its purpose as twofold: "...to produce a combination of dictionary and thesaurus that is more intuitively usable, and to support automatic text analysis and artificial intelligence applications." [History of Information](https://www.historyofinformation.com/detail.php?id=2104). This is well suited for our purpose.
#
# Use [this website](http://wordnetweb.princeton.edu/perl/webwn?s=jungle&sub=Search+WordNet&o2=1&o0=&o8=1&o1=1&o7=&o5=&o9=&o6=&o3=&o4=&h=000) to test WordNet.

# %%
nlp.add_pipe(WordnetAnnotator(nlp.lang), after='tagger')

# %% [markdown]
# **Additional technical information on pipe**:
#
# Language class and pipe description: Usually you’ll load this once per process as nlp and pass the instance around your application. The Language class is created when you call spacy.load() and contains the shared vocabulary and language data, optional model data loaded from a model package or a path, and a processing pipeline containing components like the tagger or parser that are called on a document in order. You can also add your own processing pipeline components that take a Doc object, modify it and return it.

# %% [markdown]
# #### Step 4: Find Synonyms to Trope Words

# %% [markdown]
# Start by loading the existing trope words as a list.

# %%
conflictArray = {"war","conflict","armed","weapon","pirate","attack","kill","death","dead","murder","fear","menace","smuggled weapons","smugglers","crime","gang","ransom","execution","shot","death","pain","suffer","civil war","chaos","gun","gunshot"}
generalizationArray = {"africa","african", "subsaharan africa","sub-saharan africa","continent"}
tribalismArray = {"tribe", "tribal", "tribalism", "tribalistic", "ethnic", "ethnicity"}
wildlifeArray = {"savannah","rainforest","jungle","trees","insect","lion","rhino","hunt","big game"}

all_tropes_dict = {"conflictArray":conflictArray, "generalizationArray":generalizationArray, "tribalismArray":tribalismArray, "wildlifeArray":wildlifeArray}

# %% [markdown]
# Define a function that extracts the synonyms:

# %%
def find_synonym(all_tropes_dict):
    
    all_synonyms = {}
    
    for trope in all_tropes_dict:
        synonyms_per_trope = {}
        for word in all_tropes_dict[trope]:
            unique_synonyms_per_word = set()
            token = nlp(word)[0]
            synonym_raw_outputs = token._.wordnet.synsets()
            for synonym in synonym_raw_outputs:
                word_wo_extra_info = synonym.name()[:-5]
                unique_synonyms_per_word.add(word_wo_extra_info)
            synonyms_per_trope[word] = unique_synonyms_per_word
        all_synonyms[trope] = synonyms_per_trope
            
    
    return all_synonyms

# %% [markdown]
# Let's run our dictionaries through this function.

# %%
synonyms_with_old_list = find_synonym(all_tropes_dict)

# %% [markdown]
# **Conclusion**:
#
# Surprisingly, these word sets are very limited. I crosschecked these outcomes against one of the most comprehensive dictionaries online, [Vocabulary.com](https://www.vocabulary.com) and discovered that **the words in the tropes indeed have very limited number of synonyms**.
#
# There are two courses of action going forward:
#
# 1. Try to find more words for the tropes
# 2. Try to extract more synonyms from these given words using root words ('go' for 'went', or 'run' for 'running') called lemmatization.
#
# I believe Option 1 is the most effective course of action for now. I will research related words online. After we find a comprehensive enough dictionary online, we can explore option 2 to extract the synonym of this new found dictionary.

# %% [markdown]
# ## Part II: Improved after Discussion
#
# We have decided that the current version of the Generalization array is complete. We will add a few words to the Tribalism array and we have scraped [this website](http://www.rhymezone.com/r/rhyme.cgi?Word=wildlife&org1=syl&org2=l&typeofrhyme=rel&org3=y) to complete the wildlife array. The output of this stage will be a complete versions of the Generalization, Tribalism, and Wildlife arrays. We have decided to use a different approach for the conflict array to be described in another notebook.
#
# Let's start by compiling the updated versions of the three target arrays.

# %%
generalizationArray = {"africa","african", "subsaharan africa","sub-saharan africa","continent"}
tribalismArray = {"tribe", "tribal", "tribalism", "tribalistic", "ethnic", "ethnicity", "ethnicism", "ethno", "bushmen", "pygmy", "bantu", "San people", "nomadic"}
wildlifeArray = {"acacia",
"african elephant",
"alligators",
"amazonian",
"amphibians",
"amphibiology",
"animal",
"animalness",
"animals",
"antelope",
"aquatic",
"aquatic bird",
"arctic",
"asylum",
"atlas",
"bald eagle",
"big bend national park",
"big game",
"bighorn",
"bighorn sheep",
"biocenosis",
"biodiversity",
"biosphere",
"biota",
"bird",
"bird of passage",
"bird sanctuary",
"bird table",
"birdcatching",
"birdlet",
"birdlife",
"birdling",
"birds",
"birdwatch",
"black grouse",
"bladder senna",
"bobcat",
"bobolink",
"bobwhite quail",
"bountiful",
"brimming",
"broads",
"buffalo",
"canadian goose",
"capercaillie",
"capitol reef national park",
"capturing",
"cattle",
"chimpanzee",
"chronic wasting disease",
"coastal",
"colutea arborescens",
"conifers",
"conservancy",
"conservation",
"conservationist",
"conservationists",
"conserve",
"conserved",
"conserving",
"cougars",
"countryside",
"coyotes",
"creek",
"curios",
"ddt",
"decimated",
"decimation",
"deer",
"deer mouse",
"deerfly",
"desert tortoise",
"dinotherium",
"diorama",
"dotterel",
"ducks",
"eagles",
"eaten",
"echinochloa frumentacea",
"ecology",
"ecosystem",
"ecosystems",
"ecotourism",
"elephant",
"elephant bird",
"elephants",
"elk",
"encounter",
"encounters",
"encourage",
"endanger",
"endangered",
"endangered species",
"endangering",
"endemic",
"environmental",
"eskimo curlew",
"everglades",
"exhibits",
"exotic",
"exterminated",
"extermination",
"extinction",
"faun",
"fauna",
"fish",
"fisheries",
"fishing",
"flora",
"foliage",
"forage",
"forest",
"forest ranger",
"forestry",
"forests",
"foxes",
"freshwater",
"frigate bird",
"furbearer",
"gamekeeper",
"gayal",
"geese",
"geology",
"geriatric",
"giraffe",
"gnatcatchers",
"gorilla",
"goshawk",
"grizzlies",
"grizzly bear",
"ground",
"guacharo",
"guadalupe fur seal",
"habitat",
"habitats",
"hairbird",
"hellbender",
"herbivores",
"herds",
"herpetology",
"houbara",
"indian elephant",
"insect",
"insects",
"invertebrates",
"japanese millet",
"jasper national park",
"jungle",
"kangaroo rat",
"kruger national park",
"leopard",
"leopards",
"lion",
"livestock",
"mammal",
"mammalian",
"mammals",
"marine",
"marine animal",
"migrating",
"migratory",
"monarch butterfly",
"monkey",
"mule deer",
"nocturnal",
"nongame",
"norfolk",
"oilbird",
"ornithologist",
"ortygan",
"otters",
"paguma",
"paleornithology",
"panther",
"park",
"prairie chicken",
"prairie dog",
"prairie grouse",
"prairie rattlesnake",
"prairie wolf",
"predatory animal",
"preservationist",
"procyonid",
"profusion",
"pronghorn",
"ptarmigans",
"rabbits",
"rain forest",
"rangership",
"raptor",
"raptors",
"reptiles",
"reservation",
"rhino",
"river otter",
"ruthless",
"safari",
"safari park",
"safeguard",
"sage grouse",
"sanctuaries",
"sanctuary",
"sandhill crane",
"sanwa millet",
"sar",
"sauvage",
"savage",
"savannah",
"save",
"saving",
"scenery",
"scenic",
"scenics",
"sea cow",
"sea elephant",
"sea leopard",
"seabird",
"seabirds",
"seafowl",
"seals",
"seeing",
"serengeti",
"seriema",
"shellfish",
"shoot",
"shooting",
"shore bird",
"shorebird",
"sightings",
"snail darter",
"snowshoe hare",
"songbirds",
"squirrels",
"stone curlew",
"sungrebe",
"taxonomic group",
"terrain",
"terrestrial",
"thremmatology",
"toll",
"tortoises",
"trees",
"tropical",
"tropical rain forest",
"vegetation",
"vertebrate",
"water rail",
"waterbirds",
"waterfalls",
"waterfowl",
"watershed",
"watersheds",
"waterways",
"weka",
"wetland",
"wetlands",
"whales",
"whitetail deer",
"whooping crane",
"wild",
"wild dog",
"wildflower",
"wildflowers",
"wildfowl",
"wildgrave",
"wildland",
"wildlife",
"willow grouse",
"wolves",
"wood stork",
"woodland",
"woodland caribou",
"woodlands",
"woods",
"wrybill",
"xerosere",
"zebra",
"zoo",
"zoographer",
"zoography",
"zoological",
"zoological garden",
"zoopathology",
"zoophagy",
"zootechnics",
"zootrophic"}

# Remove conflict from all tropes
all_tropes_dict = {"generalizationArray":generalizationArray, "tribalismArray":tribalismArray, "wildlifeArray":wildlifeArray}

# %% [markdown]
# Find synonyms for all these words and store them

# %%
all_three_tropes_synonyms = find_synonym(all_tropes_dict)

all_three_tropes_synonyms
# Out:
# {'generalizationArray': {'continent': {'celibate', 'continent'},
#   'africa': {'africa'},
#   'subsaharan africa': set(),
#   'african': {'african'},
#   'sub-saharan africa': set()},
#  'tribalismArray': {'ethnic': {'cultural', 'heathen'},
#   'tribalistic': set(),
#   'tribalism': {'tribalism'},
#   'nomadic': {'mobile'},
#   'ethnicism': set(),
#   'bushmen': {'bushman'},
#   'San people': set(),
#   'tribe': {'kin', 'tribe'},
#   'pygmy': {'pygmy'},
#   'ethnicity': {'ethnicity'},
#   'bantu': {'bantu'},
#   'tribal': {'tribal'},
#   'ethno': set()},
#  'wildlifeArray': {'marine animal': {'marine', 'nautical'},
#   'leopards': {'leopard'},
#   'bird of passage': {'bird', 'boo', 'dame', 'shuttlecock'},
#   'rabbits': {'lapin', 'rabbit'},
#   'foxes': {'dodger', 'fox'},
#   'endanger': {'endanger', 'queer'},
#   'pronghorn': {'pronghorn'},
#   'elephants': {'elephant'},
#   'rain forest': {'rain'},
#   'sauvage': set(),
#   'ornithologist': {'ornithologist'},
#   'broads': {'broad'},
#   'dotterel': {'dotterel'},
#   'elephant': {'elephant'},
#   'kruger national park': {'kruger'},
#   'shooting': {'blast',
#    'dart',
#    'film',
#    'fritter',
#    'inject',
#    'photograph',
#    'shoot',
#    'tear'},
#   'tropical rain forest': {'tropical'},
#   'bobwhite quail': {'bobwhite'},
#   'waterfowl': {'waterfowl'},
#   'taxonomic group': {'taxonomic'},
#   'countryside': {'countryside'},
#   'paleornithology': {'paleornithology'},
#   'wildfowl': {'wildfowl'},
#   'conservancy': {'conservancy'},
#   'marine': {'marine', 'nautical'},
#   'bird table': {'bird', 'boo', 'dame', 'shuttlecock'},
#   'conservationist': {'environmentalist'},
#   'encourage': {'encourage', 'promote'},
#   'reservation': {'booking', 'mental_reservation', 'reservation'},
#   'bobcat': {'bobcat'},
#   'fish': {'fish', 'pisces'},
#   'wildflowers': {'wildflower'},
#   'nocturnal': {'nocturnal'},
#   'acacia': {'acacia'},
#   'habitats': {'habitat'},
#   'fauna': {'animal', 'fauna'},
#   'eagles': {'eagle'},
#   'flora': {'plant', 'vegetation'},
#   'livestock': {'livestock'},
#   'zoography': set(),
#   'curios': {'curio'},
#   'insects': {'insect', 'worm'},
#   'wolves': {'beast', 'wolf'},
#   'ground': {'background',
#    'earth',
#    'flat_coat',
#    'footing',
#    'ground',
#    'land',
#    'reason'},
#   'leopard': {'leopard'},
#   'xerosere': set(),
#   'gnatcatchers': {'gnatcatcher'},
#   'capturing': {'appropriate', 'capture', 'get'},
#   'sightings': {'sighting'},
#   'whitetail deer': {'virginia_deer'},
#   'faun': {'faun'},
#   'aquatic': {'aquatic'},
#   'monkey': {'imp', 'monkey', 'putter', 'tamper'},
#   'wild': {'angry',
#    'barbarian',
#    'baseless',
#    'crazy',
#    'fantastic',
#    'godforsaken',
#    'hazardous',
#    'raving_mad',
#    'violent',
#    'wild'},
#   'migrating': {'migrate'},
#   'whales': {'giant', 'whale'},
#   'mammals': {'mammal'},
#   'freshwater': set(),
#   'giraffe': {'giraffe'},
#   'seriema': {'chunga', 'crested_cariama'},
#   'wildland': set(),
#   'frigate bird': {'frigate'},
#   'songbirds': {'songbird'},
#   'lion': {'leo', 'lion'},
#   'wood stork': {'forest', 'wood', 'woodwind'},
#   'seabird': {'seabird'},
#   'birdwatch': {'bird'},
#   'endemic': {'autochthonal', 'endemic'},
#   'prairie chicken': {'prairie'},
#   'foliage': {'foliation', 'leaf'},
#   'scenics': set(),
#   'sandhill crane': set(),
#   'guacharo': {'oilbird'},
#   'profusion': {'profusion'},
#   'endangered species': {'endanger', 'queer'},
#   'jungle': {'hobo_camp', 'jungle'},
#   'mammal': {'mammal'},
#   'bird': {'bird', 'boo', 'dame', 'shuttlecock'},
#   'herpetology': {'herpetology'},
#   'brimming': {'brim'},
#   'prairie rattlesnake': {'prairie'},
#   'toll': {'bell', 'price', 'toll'},
#   'coastal': {'coastal'},
#   'birdlet': set(),
#   'save': {'deliver', 'keep_open', 'salvage', 'save', 'spare', 'write'},
#   'extinction': {'extinction'},
#   'capercaillie': {'capercaillie'},
#   'encounters': {'brush', 'confrontation', 'encounter', 'meeting'},
#   'sea cow': {'ocean', 'sea'},
#   'biosphere': set(),
#   'forage': {'eatage', 'foraging'},
#   'predatory animal': {'marauding', 'predaceous', 'predatory'},
#   'saving': {'deliver', 'keep_open', 'salvage', 'save', 'spare', 'write'},
#   'forest ranger': {'afforest', 'forest'},
#   'aquatic bird': {'aquatic'},
#   'decimation': {'decimation'},
#   'conserve': {'conserve'},
#   'tropical': {'tropical'},
#   'capitol reef national park': {'capitol'},
#   'woods': {'forest', 'wood', 'woodwind'},
#   'watershed': {'landmark', 'river_basin', 'watershed'},
#   'animal': {'animal'},
#   'safari': {'campaign'},
#   'elephant bird': {'elephant'},
#   'endangering': {'endanger', 'queer'},
#   'scenery': {'scenery'},
#   'sanctuaries': {'chancel', 'refuge', 'sanctuary'},
#   'fishing': {'fishing'},
#   'norfolk': {'norfolk'},
#   'vegetation': {'vegetation'},
#   'biocenosis': set(),
#   'monarch butterfly': {'monarch', 'sovereign'},
#   'savage': {'barbarian',
#    'barbarous',
#    'beast',
#    'feral',
#    'ferocious',
#    'savage'},
#   'biodiversity': {'biodiversity'},
#   'zoological': {'zoological'},
#   'houbara': set(),
#   'serengeti': {'serengeti'},
#   'animals': {'animal'},
#   'panther': {'cougar', 'jaguar', 'panther'},
#   'ortygan': {'ortygan'},
#   'birdling': set(),
#   'gayal': {'gayal'},
#   'water rail': {'body_of_water', 'urine', 'water', 'water_system'},
#   'exterminated': {'exterminate', 'uproot'},
#   'snowshoe hare': {'snowshoe'},
#   'bountiful': {'big', 'bountiful'},
#   'big game': {'adult', 'bad', 'big', 'boastful', 'large'},
#   'scenic': {'scenic'},
#   'sea leopard': {'ocean', 'sea'},
#   'coyotes': {'coyote'},
#   'conservationists': {'environmentalist'},
#   'sungrebe': set(),
#   'waterfalls': {'waterfall'},
#   'deer mouse': {'deer'},
#   'bighorn sheep': {'bighorn'},
#   'grizzly bear': {'grey', 'grizzly'},
#   'seabirds': {'seabird'},
#   'prairie dog': {'prairie'},
#   'migratory': {'migrant', 'migratory'},
#   'rhino': {'rhinoceros'},
#   'biota': {'biota'},
#   'sar': set(),
#   'seeing': {'attend',
#    'determine',
#    'examine',
#    'experience',
#    'go_steady',
#    'interpret',
#    'learn',
#    'meet',
#    'see',
#    'understand',
#    'visit',
#    'visualize',
#    'watch',
#    'witness'},
#   'ecosystem': {'ecosystem'},
#   'decimated': {'decimate', 'eliminate'},
#   'raptor': {'bird_of_prey'},
#   'terrestrial': {'mundane',
#    'planetary',
#    'sublunar',
#    'tellurian',
#    'terrestrial'},
#   'terrain': {'terrain'},
#   'wetlands': {'wetland'},
#   'birdcatching': set(),
#   'asylum': {'mental_hospital', 'refuge'},
#   'hairbird': set(),
#   'gorilla': {'gorilla'},
#   'woodland': {'forest'},
#   'bobolink': {'bobolink'},
#   'bird sanctuary': {'bird', 'boo', 'dame', 'shuttlecock'},
#   'oilbird': {'oilbird'},
#   'canadian goose': {'canadian'},
#   'ptarmigans': {'ptarmigan'},
#   'forestry': {'forestry'},
#   'endangered': {'endanger', 'queer'},
#   'bald eagle': {'bald'},
#   'wildlife': {'wildlife'},
#   'woodlands': {'forest'},
#   'bighorn': {'bighorn'},
#   'rangership': set(),
#   'amazonian': set(),
#   'zootrophic': set(),
#   'zoophagy': set(),
#   'raptors': {'bird_of_prey'},
#   'atlas': {'atlas'},
#   'amphibiology': set(),
#   'desert tortoise': {'abandon', 'defect', 'desert'},
#   'herds': {'herd', 'ruck'},
#   'african elephant': {'african'},
#   'guadalupe fur seal': set(),
#   'habitat': {'habitat'},
#   'seals': {'cachet', 'navy_seal', 'seal', 'sealing_wax'},
#   'ddt': {'dichlorodiphenyltrichloroethane'},
#   'zoographer': set(),
#   'animalness': set(),
#   'weka': {'weka'},
#   'arctic': {'arctic', 'north-polar'},
#   'shoot': {'blast',
#    'dart',
#    'film',
#    'fritter',
#    'inject',
#    'photograph',
#    'shoot',
#    'tear'},
#   'sea elephant': {'ocean', 'sea'},
#   'sage grouse': {'sage'},
#   'furbearer': set(),
#   'stone curlew': {'gem', 'pit', 'rock', 'stone'},
#   'extermination': {'extermination', 'extinction'},
#   'procyonid': {'procyonid'},
#   'safari park': {'campaign'},
#   'cougars': {'cougar'},
#   'wetland': {'wetland'},
#   'shorebird': {'shorebird'},
#   'park': {'ballpark', 'park', 'parking_lot'},
#   'forest': {'afforest', 'forest'},
#   'sanctuary': {'chancel', 'refuge', 'sanctuary'},
#   'zebra': {'zebra'},
#   'waterbirds': {'waterfowl'},
#   'elk': {'elk', 'red_deer', 'wapiti'},
#   'woodland caribou': {'forest'},
#   'eaten': {'consume', 'corrode', 'eat', 'feed'},
#   'goshawk': {'goshawk'},
#   'thremmatology': set(),
#   'wrybill': set(),
#   'ecosystems': {'ecosystem'},
#   'alligators': {'alligator'},
#   'chronic wasting disease': {'chronic'},
#   'shellfish': {'mollusk', 'shellfish'},
#   'ecology': {'ecology'},
#   'zoo': {'menagerie'},
#   'birds': {'bird', 'boo', 'dame', 'shuttlecock'},
#   'indian elephant': {'indian'},
#   'prairie grouse': {'prairie'},
#   'willow grouse': {'willow'},
#   'wildgrave': set(),
#   'geese': {'fathead', 'goose'},
#   'reptiles': {'reptile'},
#   'river otter': {'river'},
#   'jasper national park': {'jasper'},
#   'tortoises': {'tortoise'},
#   'big bend national park': {'adult',
#    'bad',
#    'big',
#    'boastful',
#    'boastfully',
#    'large'},
#   'echinochloa frumentacea': {'echinochloa'},
#   'hellbender': {'hellbender'},
#   'conservation': {'conservation'},
#   'eskimo curlew': {'eskimo'},
#   'zootechnics': set(),
#   'kangaroo rat': {'kangaroo'},
#   'antelope': {'antelope'},
#   'japanese millet': {'japanese'},
#   'snail darter': {'escargot', 'snail'},
#   'bladder senna': {'bladder'},
#   'waterways': {'watercourse', 'waterway'},
#   'wildflower': {'wildflower'},
#   'geology': {'geology'},
#   'preservationist': {'preservationist'},
#   'trees': {'tree'},
#   'birdlife': set(),
#   'conserved': {'conserve'},
#   'vertebrate': {'vertebrate'},
#   'cattle': {'cattle'},
#   'everglades': {'everglades'},
#   'exotic': {'alien', 'exotic'},
#   'shore bird': {'land', 'prop_up', 'shore'},
#   'mule deer': {'mule'},
#   'prairie wolf': {'prairie'},
#   'conifers': {'conifer'},
#   'otters': {'otter'},
#   'encounter': {'brush', 'confrontation', 'encounter', 'meeting'},
#   'ruthless': {'pitiless'},
#   'fisheries': {'fishery'},
#   'whooping crane': {'hack', 'whoop'},
#   'geriatric': {'geriatric'},
#   'watersheds': {'landmark', 'river_basin', 'watershed'},
#   'forests': {'forest'},
#   'chimpanzee': {'chimpanzee'},
#   'seafowl': {'seabird'},
#   'deerfly': set(),
#   'ecotourism': {'ecotourism'},
#   'zoological garden': {'zoological'},
#   'savannah': {'savanna', 'savannah'},
#   'grizzlies': {'grizzly'},
#   'exhibits': {'display', 'exhibit'},
#   'creek': {'brook', 'creek'},
#   'deer': {'deer'},
#   'gamekeeper': {'gamekeeper'},
#   'invertebrates': {'invertebrate'},
#   'conserving': {'conserve'},
#   'colutea arborescens': {'colutea'},
#   'nongame': set(),
#   'zoopathology': set(),
#   'sanwa millet': set(),
#   'environmental': {'environmental'},
#   'herbivores': {'herbivore'},
#   'paguma': set(),
#   'squirrels': {'squirrel'},
#   'safeguard': {'precaution', 'safe-conduct', 'safeguard'},
#   'wild dog': {'angry',
#    'barbarian',
#    'baseless',
#    'crazy',
#    'fantastic',
#    'godforsaken',
#    'hazardous',
#    'raving_mad',
#    'violent',
#    'wild'},
#   'insect': {'insect', 'worm'},
#   'buffalo': {'american_bison', 'buffalo', 'old_world_buffalo'},
#   'ducks': {'duck'},
#   'diorama': {'panorama'},
#   'dinotherium': set(),
#   'amphibians': {'amphibian'},
#   'black grouse': {'black', 'bootleg'},
#   'mammalian': {'mammalian'}}}

# %%
print("Generalization has {} unique words.".format(len(all_three_tropes_synonyms["generalizationArray"])))
print("Tribalism has {} unique words.".format(len(all_three_tropes_synonyms["tribalismArray"])))
print("Wildlife has {} unique words.".format(len(all_three_tropes_synonyms["wildlifeArray"])))
# Out:
# Generalization has 5 unique words.
# Tribalism has 13 unique words.
# Wildlife has 286 unique words.

# %% [markdown]
# From the synonyms, we have 331 unique wildlife, 18 tribalism, and 7 generalization array words.

# %% [markdown]
# ~ THE END OF NOTEBOOK ~

# %%
all_three_tropes_synonyms["generalizationArray"]
# Out:
# {'continent': {'celibate', 'continent'},
#  'africa': {'africa'},
#  'subsaharan africa': set(),
#  'african': {'african'},
#  'sub-saharan africa': set()}
